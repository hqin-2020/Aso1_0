# %%
import numpy as np
import scipy as sp
import pandas as pd
import sobol
import os
import time
from concurrent.futures import ProcessPoolExecutor
import seaborn as sns
from Minimization import minimization
import pickle
obs_series = pd.read_csv('data.csv', delimiter=',')
obs_series = np.array(obs_series.iloc[:,1:]).T
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 8>()
#       6 import time
#       7 from concurrent.futures import ProcessPoolExecutor
# ----> 8 import seaborn as sns
#       9 from Minimization import minimization
#      10 import pickle
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/__init__.py:2, in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/rcmod.py:7, in <module>
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes
#      10 __all__ = ["set_theme", "set", "reset_defaults", "reset_orig",
#      11            "axes_style", "set_style", "plotting_context", "set_context",
#      12            "set_palette"]
#      15 _style_keys = [
#      16
#      17     "axes.facecolor",
#    (...)
#      52
#      53 ]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/palettes.py:9, in <module>
#       5 import matplotlib as mpl
#       7 from .external import husl
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      13 __all__ = ["color_palette", "hls_palette", "husl_palette", "mpl_palette",
#      14            "dark_palette", "light_palette", "diverging_palette",
#      15            "blend_palette", "xkcd_palette", "crayon_palette",
#      16            "cubehelix_palette", "set_color_codes"]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/utils.py:14, in <module>
#      12 import matplotlib as mpl
#      13 import matplotlib.colors as mplcol
# ---> 14 import matplotlib.pyplot as plt
#      15 from matplotlib.cbook import normalize_kwargs
#      18 __all__ = ["desaturate", "saturate", "set_hls_values", "move_legend",
#      19            "despine", "get_dataset_names", "get_data_home", "load_dataset"]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:49, in <module>
#      47 from cycler import cycler
#      48 import matplotlib
# ---> 49 import matplotlib.colorbar
#      50 import matplotlib.image
#      51 from matplotlib import _api
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/colorbar.py:26, in <module>
#      24 import matplotlib.path as mpath
#      25 import matplotlib.scale as mscale
# ---> 26 import matplotlib.spines as mspines
#      27 import matplotlib.transforms as mtransforms
#      28 from matplotlib import docstring
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/spines.py:14, in <module>
#      10 import matplotlib.patches as mpatches
#      11 import matplotlib.path as mpath
# ---> 14 class Spine(mpatches.Patch):
#      15     """
#      16     An axis spine -- the line noting the data area boundaries.
#      17
#    (...)
#      29
#      30     """
#      31     def __str__(self):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:119, in Artist.__init_subclass__(cls)
#     117 cls.set.__name__ = "set"
#     118 cls.set.__qualname__ = f"{cls.__qualname__}.set"
# --> 119 cls._update_set_signature_and_docstring()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:140, in Artist._update_set_signature_and_docstring(cls)
#     128 @classmethod
#     129 def _update_set_signature_and_docstring(cls):
#     130     """
#     131     Update the signature of the set function to list all properties
#     132     as keyword arguments.
#    (...)
#     135     are still accepted as keyword arguments.
#     136     """
#     137     cls.set.__signature__ = Signature(
#     138         [Parameter("self", Parameter.POSITIONAL_OR_KEYWORD),
#     139          *[Parameter(prop, Parameter.KEYWORD_ONLY, default=_UNSET)
# --> 140            for prop in ArtistInspector(cls).get_setters()
#     141            if prop not in Artist._PROPERTIES_EXCLUDED_FROM_SET]])
#     142     cls.set._autogenerated_signature = True
#     144     cls.set.__doc__ = (
#     145         "Set multiple properties at once.\n\n"
#     146         "Supported properties are\n\n"
#     147         + kwdoc(cls))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:1345, in ArtistInspector.__init__(self, o)
#    1342     o = type(o)
#    1343 self.o = o
# -> 1345 self.aliasd = self.get_aliases()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:1364, in ArtistInspector.get_aliases(self)
#    1362 for name in names:
#    1363     func = getattr(self.o, name)
# -> 1364     if not self.is_alias(func):
#    1365         continue
#    1366     propname = re.search("`({}.*)`".format(name[:4]),  # get_.*/set_.*
#    1367                          inspect.getdoc(func)).group(1)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:1443, in ArtistInspector.is_alias(self, o)
#    1441 def is_alias(self, o):
#    1442     """Return whether method object *o* is an alias for another method."""
# -> 1443     ds = inspect.getdoc(o)
#    1444     if ds is None:
#    1445         return False
#
# File ~/opt/anaconda3/lib/python3.9/inspect.py:624, in getdoc(object)
#     622 if not isinstance(doc, str):
#     623     return None
# --> 624 return cleandoc(doc)
#
# File ~/opt/anaconda3/lib/python3.9/inspect.py:647, in cleandoc(doc)
#     645     lines[0] = lines[0].lstrip()
#     646 if margin < sys.maxsize:
# --> 647     for i in range(1, len(lines)): lines[i] = lines[i][margin:]
#     648 # Remove any trailing or leading blank lines.
#     649 while lines and not lines[-1]:
#
# KeyboardInterrupt:

# %%
n_points = 100
sobol_sequence = sobol.sample(dimension=21, n_points=n_points)
sobol_sequence[:,1:] = sobol_sequence[:,1:]*2 -1
start = np.array_split(sobol_sequence, n_points)

# %%
start_time = time.time()
if __name__ == '__main__':
    with ProcessPoolExecutor() as pool:
        results = pool.map(minimization, start)
    results = [r for r in results]
run_time = time.time() - start_time
